# %%
# !pip install geopandas pandas matplotlib folium
# Out:
# Requirement already satisfied: geopandas in c:\users\agnes\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: pandas in c:\users\agnes\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\agnes\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: folium in c:\users\agnes\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\agnes\anaconda3\lib\site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: packaging in c:\users\agnes\anaconda3\lib\site-packages (from geopandas) (22.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\agnes\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\agnes\anaconda3\lib\site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\agnes\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\agnes\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agnes\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pillow>=8 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\agnes\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: jinja2>=2.9 in c:\users\agnes\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\agnes\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in c:\users\agnes\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: munch>=2.3.2 in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2.5.0)
# Requirement already satisfied: certifi in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2025.1.31)
# Requirement already satisfied: click~=8.0 in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\agnes\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agnes\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\agnes\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\agnes\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\agnes\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agnes\anaconda3\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: colorama in c:\users\agnes\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\agnes\anaconda3\lib\site-packages)

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
## ---------- INKAR DATEN -----------

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_cleaned_zensus.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)

# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'Bruttoinlandsprodukt je Einwohner_2021'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()


# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\INKAR\processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Gehe über jede numerische Spalte und erstelle ein PNG
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    try:
        # 2. Definiere den Min-Max-Wertebereich für die Farbskala
        vmin = merged[column_name].min()
        vmax = merged[column_name].max()

        # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
        fig, ax = plt.subplots(1, 1, figsize=(10, 10))

        # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
        merged.plot(column=column_name, ax=ax, legend=True,
                    legend_kwds={'orientation': "vertical"},
                    vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

        # 4. Titel und Anzeige der Karte
        plt.title(column_name, fontsize=18)

        # Speichern der Karte als PNG
        output_file = os.path.join(output_dir, f"{column_name}.png")
        plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

        # Schließe die Figur, um den Speicher zu freizugeben
        plt.close(fig)

        print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

    except Exception as e:
        print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")

# %%
## ---------- MODIS DATEN -----------

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_mean_NDVI_values.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'NDVI_DJF_23_24'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='Greens')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()




# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs"  # Passe den Pfad an


# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Gehe über jede numerische Spalte und erstelle ein PNG
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    try:
        # 2. Definiere den Min-Max-Wertebereich für die Farbskala
        vmin = merged[column_name].min()
        vmax = merged[column_name].max()

        # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
        fig, ax = plt.subplots(1, 1, figsize=(10, 10))

        # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
        merged.plot(column=column_name, ax=ax, legend=True,
                    legend_kwds={'orientation': "vertical"},
                    vmin=vmin, vmax=vmax, cmap='Greens')  # 'plasma' als kontrastreiche Farbpalette

        # 4. Titel und Anzeige der Karte
        plt.title(column_name, fontsize=18)

        # Speichern der Karte als PNG
        output_file = os.path.join(output_dir, f"{column_name}.png")
        plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

        # Schließe die Figur, um den Speicher zu freizugeben
        plt.close(fig)

        print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

    except Exception as e:
        print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['AGS', 'ARS', 'GF', 'GEN', 'BEZ', 'NDVI_DJF_23_24', 'NDVI_JJA_24',
#        'NDVI_MAM_24', 'NDVI_SON_24'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 2  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
# 3  DEBKGVG200000C78  2022-12-20    4   4    1  01004  01004  010040000000
# 4  DEBKGVG200000C79  2023-10-04    4   4    1  01051  01051  010510044044
#
#             GEN               BEZ  ...   NUTS         ARS_0     AGS_0  \
# 0     Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 1          Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 2        Lübeck  Kreisfreie Stadt  ...  DEF03  010030000000  01003000
# 3    Neumünster  Kreisfreie Stadt  ...  DEF04  010040000000  01004000
# 4  Dithmarschen             Kreis  ...  DEF05  010510000000  01051000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2006-01-01  DEBKGDL20000E43X
# 2  2006-02-01  DEBKGDL20000DYM9
# 3  1970-04-26  DEBKGDL20000E4KX
# 4  2011-08-01  DEBKGDL20000E14G
#
#                                             geometry NDVI_DJF_23_24  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...       0.480686
# 1  POLYGON ((3575940.276 6034122.503, 3575968.387...       0.434920
# 2  POLYGON ((3623175.007 5985702.682, 3623310.494...       0.440358
# 3  POLYGON ((3565110.702 6002599.225, 3565223.516...       0.512774
# 4  MULTIPOLYGON (((3479734.380 5992192.193, 34798...       0.525503
#
#   NDVI_JJA_24 NDVI_MAM_24 NDVI_SON_24
# 0    0.677135    0.548549    0.628363
# 1    0.675550    0.608622    0.629214
# 2    0.660054    0.589503    0.603183
# 3    0.689680    0.630917    0.655018
# 4    0.711748    0.664871    0.661577
#
# [5 rows x 30 columns]
# ✓ Datei für ADE erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\ADE.png
# ✓ Datei für GF erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\GF.png
# ✓ Datei für BSG erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\BSG.png
# ✓ Datei für IBZ erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\IBZ.png
# ✓ Datei für NDVI_DJF_23_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\NDVI_DJF_23_24.png
# ✓ Datei für NDVI_JJA_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\NDVI_JJA_24.png
# ✓ Datei für NDVI_MAM_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\NDVI_MAM_24.png
# ✓ Datei für NDVI_SON_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs\NDVI_SON_24.png

# %%
## ---------- MODIS DATEN -----------

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_mean_NO2_values.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'NDVI_DJF_23_24'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='Greens')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()




# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\MODIS\MODIS_061_MOD13A3\processed_pngs"  # Passe den Pfad an


# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Gehe über jede numerische Spalte und erstelle ein PNG
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    try:
        # 2. Definiere den Min-Max-Wertebereich für die Farbskala
        vmin = merged[column_name].min()
        vmax = merged[column_name].max()

        # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
        fig, ax = plt.subplots(1, 1, figsize=(10, 10))

        # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
        merged.plot(column=column_name, ax=ax, legend=True,
                    legend_kwds={'orientation': "vertical"},
                    vmin=vmin, vmax=vmax, cmap='Greens')  # 'plasma' als kontrastreiche Farbpalette

        # 4. Titel und Anzeige der Karte
        plt.title(column_name, fontsize=18)

        # Speichern der Karte als PNG
        output_file = os.path.join(output_dir, f"{column_name}.png")
        plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

        # Schließe die Figur, um den Speicher zu freizugeben
        plt.close(fig)

        print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

    except Exception as e:
        print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")

# %%
## ---------- SENTINEL-5P DATEN -----------

## NO2

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_mean_NO2_values.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'NO2_DJF_23_24'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_NO2\processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['AGS', 'ARS', 'GF', 'GEN', 'BEZ', 'NO2_DJF_23_24', 'NO2_JJA_24',
#        'NO2_MAM_24', 'NO2_SON_24'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 2  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
# 3  DEBKGVG200000C78  2022-12-20    4   4    1  01004  01004  010040000000
# 4  DEBKGVG200000C79  2023-10-04    4   4    1  01051  01051  010510044044
#
#             GEN               BEZ  ...   NUTS         ARS_0     AGS_0  \
# 0     Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 1          Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 2        Lübeck  Kreisfreie Stadt  ...  DEF03  010030000000  01003000
# 3    Neumünster  Kreisfreie Stadt  ...  DEF04  010040000000  01004000
# 4  Dithmarschen             Kreis  ...  DEF05  010510000000  01051000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2006-01-01  DEBKGDL20000E43X
# 2  2006-02-01  DEBKGDL20000DYM9
# 3  1970-04-26  DEBKGDL20000E4KX
# 4  2011-08-01  DEBKGDL20000E14G
#
#                                             geometry NO2_DJF_23_24 NO2_JJA_24  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...     13.703169  24.073328
# 1  POLYGON ((3575940.276 6034122.503, 3575968.387...      5.749211  27.583841
# 2  POLYGON ((3623175.007 5985702.682, 3623310.494...     15.143479  27.990016
# 3  POLYGON ((3565110.702 6002599.225, 3565223.516...     -1.775957  27.340724
# 4  MULTIPOLYGON (((3479734.380 5992192.193, 34798...     11.545278  24.584295
#
#   NO2_MAM_24 NO2_SON_24
# 0  30.634867  37.776449
# 1  34.607549  40.018888
# 2  34.900733  43.221958
# 3  34.706406  41.861804
# 4  37.540513  43.660933
#
# [5 rows x 30 columns]
# ✓ Datei für NO2_DJF_23_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_NO2\processed_pngs\NO2_DJF_23_24.png
# ✓ Datei für NO2_JJA_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_NO2\processed_pngs\NO2_JJA_24.png
# ✓ Datei für NO2_MAM_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_NO2\processed_pngs\NO2_MAM_24.png
# ✓ Datei für NO2_SON_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_NO2\processed_pngs\NO2_SON_24.png

# %%
## ---------- SENTINEL-5P DATEN -----------

## SO2

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_SO2_values.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'NO2_DJF_23_24'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_SO2\processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['AGS', 'ARS', 'GF', 'GEN', 'BEZ', 'SO2_DJF_23_24', 'SO2_JJA_24',
#        'SO2_MAM_24', 'SO2_SON_24'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 2  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
# 3  DEBKGVG200000C78  2022-12-20    4   4    1  01004  01004  010040000000
# 4  DEBKGVG200000C79  2023-10-04    4   4    1  01051  01051  010510044044
#
#             GEN               BEZ  ...   NUTS         ARS_0     AGS_0  \
# 0     Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 1          Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 2        Lübeck  Kreisfreie Stadt  ...  DEF03  010030000000  01003000
# 3    Neumünster  Kreisfreie Stadt  ...  DEF04  010040000000  01004000
# 4  Dithmarschen             Kreis  ...  DEF05  010510000000  01051000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2006-01-01  DEBKGDL20000E43X
# 2  2006-02-01  DEBKGDL20000DYM9
# 3  1970-04-26  DEBKGDL20000E4KX
# 4  2011-08-01  DEBKGDL20000E14G
#
#                                             geometry SO2_DJF_23_24 SO2_JJA_24  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...           NaN  38.659569
# 1  POLYGON ((3575940.276 6034122.503, 3575968.387...           NaN  57.197799
# 2  POLYGON ((3623175.007 5985702.682, 3623310.494...           NaN   9.362357
# 3  POLYGON ((3565110.702 6002599.225, 3565223.516...           NaN  49.300844
# 4  MULTIPOLYGON (((3479734.380 5992192.193, 34798...           NaN   0.286322
#
#    SO2_MAM_24  SO2_SON_24
# 0   97.862457  176.966390
# 1  217.604432  196.513375
# 2  163.338668  200.730092
# 3  133.520013   71.778534
# 4  144.165715  166.960492
#
# [5 rows x 30 columns]
# ✓ Datei für SO2_DJF_23_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_SO2\processed_pngs\SO2_DJF_23_24.png
# ✓ Datei für SO2_JJA_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_SO2\processed_pngs\SO2_JJA_24.png
# ✓ Datei für SO2_MAM_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_SO2\processed_pngs\SO2_MAM_24.png
# ✓ Datei für SO2_SON_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_SO2\processed_pngs\SO2_SON_24.png

# %%
## ---------- SENTINEL-5P DATEN -----------

## O3

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/combined_O3_values.csv"
df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'NO2_DJF_23_24'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = r"C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_O3\processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['AGS', 'ARS', 'GF', 'GEN', 'BEZ', 'O3_DJF_23_24', 'O3_JJA_24',
#        'O3_MAM_24', 'O3_SON_24'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 2  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
# 3  DEBKGVG200000C78  2022-12-20    4   4    1  01004  01004  010040000000
# 4  DEBKGVG200000C79  2023-10-04    4   4    1  01051  01051  010510044044
#
#             GEN               BEZ  ...   NUTS         ARS_0     AGS_0  \
# 0     Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 1          Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 2        Lübeck  Kreisfreie Stadt  ...  DEF03  010030000000  01003000
# 3    Neumünster  Kreisfreie Stadt  ...  DEF04  010040000000  01004000
# 4  Dithmarschen             Kreis  ...  DEF05  010510000000  01051000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2006-01-01  DEBKGDL20000E43X
# 2  2006-02-01  DEBKGDL20000DYM9
# 3  1970-04-26  DEBKGDL20000E4KX
# 4  2011-08-01  DEBKGDL20000E14G
#
#                                             geometry   O3_DJF_23_24  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...  153804.288695
# 1  POLYGON ((3575940.276 6034122.503, 3575968.387...  153923.179117
# 2  POLYGON ((3623175.007 5985702.682, 3623310.494...  153782.559337
# 3  POLYGON ((3565110.702 6002599.225, 3565223.516...  153259.319749
# 4  MULTIPOLYGON (((3479734.380 5992192.193, 34798...  153290.456744
#
#        O3_JJA_24      O3_MAM_24      O3_SON_24
# 0  156502.127906  172979.179727  130717.162168
# 1  156026.057762  173403.634372  130741.777009
# 2  155511.713408  172563.027733  130755.866361
# 3  155476.712327  173359.994090  130883.445235
# 4  155800.437664  173983.117383  130814.534465
#
# [5 rows x 30 columns]
# ✓ Datei für O3_DJF_23_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_O3\processed_pngs\O3_DJF_23_24.png
# ✓ Datei für O3_JJA_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_O3\processed_pngs\O3_JJA_24.png
# ✓ Datei für O3_MAM_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_O3\processed_pngs\O3_MAM_24.png
# ✓ Datei für O3_SON_24 erfolgreich gespeichert als C:\Users\agnes\Documents\EAGLE\Innovation_Lab\Daten\Sentinel_5P\OFFL_L3_O3\processed_pngs\O3_SON_24.png

# %%
## ---------- DWD-DATEN -----------

## Tropennächte

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/Tropennaechte_2022_Jahresdaten.csv"

df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'Tropennaechte_mean'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/UHI/Tropische_Naechte/Jaehrlich/by_year/processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['ID','AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['ID', 'ARS', 'AGS', 'GEN', 'BEZ', 'Tropennaechte_mean',
#        'Tropennaechte_median', 'Tropennaechte_max'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 2  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 3  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 4  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
#
#          GEN               BEZ  ...   NUTS         ARS_0     AGS_0  \
# 0  Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 1  Flensburg  Kreisfreie Stadt  ...  DEF01  010010000000  01001000
# 2       Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 3       Kiel  Kreisfreie Stadt  ...  DEF02  010020000000  01002000
# 4     Lübeck  Kreisfreie Stadt  ...  DEF03  010030000000  01003000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2008-01-01  DEBKGDL20000002R
# 2  2006-01-01  DEBKGDL20000E43X
# 3  2006-01-01  DEBKGDL20000E43X
# 4  2006-02-01  DEBKGDL20000DYM9
#
#                                             geometry   ID Tropennaechte_mean  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...    1           0.482252
# 1  POLYGON ((3526591.850 6077123.907, 3526626.055...  401           0.000000
# 2  POLYGON ((3575940.276 6034122.503, 3575968.387...    2           1.333722
# 3  POLYGON ((3575940.276 6034122.503, 3575968.387...  402           1.044283
# 4  POLYGON ((3623175.007 5985702.682, 3623310.494...    3           1.330054
#
#   Tropennaechte_median Tropennaechte_max
# 0             0.000000          6.564616
# 1             0.000000          0.000000
# 2             0.823582         15.413910
# 3             1.000000          1.177134
# 4             0.803884         15.008608
#
# [5 rows x 30 columns]
# ✓ Datei für Tropennaechte_mean erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/UHI/Tropische_Naechte/Jaehrlich/by_year/processed_pngs\Tropennaechte_mean.png
# ✓ Datei für Tropennaechte_median erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/UHI/Tropische_Naechte/Jaehrlich/by_year/processed_pngs\Tropennaechte_median.png
# ✓ Datei für Tropennaechte_max erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/UHI/Tropische_Naechte/Jaehrlich/by_year/processed_pngs\Tropennaechte_max.png

# %%
## ---------- DWD-DATEN -----------

## Temperatur

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/Stats_Temp_Jaehrlich.csv"

df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['ID','AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['ID', 'ARS', 'AGS', 'GEN', 'BEZ',
#        'annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean',
#        'annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_median',
#        'annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_mean',
#        'annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_median',
#        'annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_mean',
#        'annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_median'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 2  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 3  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 4  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
#
#          GEN               BEZ  ...         WSK            DLM_ID  \
# 0  Flensburg  Kreisfreie Stadt  ...  2008-01-01  DEBKGDL20000002R
# 1  Flensburg  Kreisfreie Stadt  ...  2008-01-01  DEBKGDL20000002R
# 2       Kiel  Kreisfreie Stadt  ...  2006-01-01  DEBKGDL20000E43X
# 3       Kiel  Kreisfreie Stadt  ...  2006-01-01  DEBKGDL20000E43X
# 4     Lübeck  Kreisfreie Stadt  ...  2006-02-01  DEBKGDL20000DYM9
#
#                                             geometry   ID  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...    1
# 1  POLYGON ((3526591.850 6077123.907, 3526626.055...  401
# 2  POLYGON ((3575940.276 6034122.503, 3575968.387...    2
# 3  POLYGON ((3575940.276 6034122.503, 3575968.387...  402
# 4  POLYGON ((3623175.007 5985702.682, 3623310.494...    3
#
#   annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean  \
# 0                                          13.887500
# 1                                                NaN
# 2                                          14.167568
# 3                                                NaN
# 4                                          14.633158
#
#   annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_median  \
# 0                                               13.9
# 1                                                NaN
# 2                                               14.2
# 3                                                NaN
# 4                                               14.7
#
#   annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_mean  \
# 0                                          10.033333
# 1                                                NaN
# 2                                          10.375676
# 3                                                NaN
# 4                                          10.304211
#
#   annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_median  \
# 0                                               10.0
# 1                                                NaN
# 2                                               10.4
# 3                                                NaN
# 4                                               10.3
#
#   annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_mean  \
# 0                                           6.145833
# 1                                                NaN
# 2                                           6.459459
# 3                                                NaN
# 4                                           5.711053
#
#   annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_median
# 0                                                6.1
# 1                                                NaN
# 2                                                6.4
# 3                                                NaN
# 4                                                5.6
#
# [5 rows x 33 columns]
# ✓ Datei für annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean.png
# ✓ Datei für annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_median erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_median.png
# ✓ Datei für annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_mean erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_mean.png
# ✓ Datei für annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_median erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_mean_grids_germany_annual_air_temp_mean_202217_median.png
# ✓ Datei für annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_mean erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_mean.png
# ✓ Datei für annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_median erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Temperatur/Jaehrlich/processed_pngs\annual_air_temperature_min_grids_germany_annual_air_temp_min_202217_median.png

# %%
## ---------- DWD-DATEN -----------

## Niederschlag

# 1. Shapefile laden
shapefile_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Verwaltungsgebiete/vg250_12-31.gk3.shape.ebenen/vg250_ebenen_1231/VG250_KRS.shp"
gdf = gpd.read_file(shapefile_path, dtype={'ARS': str})

# 2. CSV-Daten laden
csv_file_path = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/Zusammenfassung_20250508/Stats_Prec_Jaehrlich.csv"

df = pd.read_csv(csv_file_path, dtype={'ARS': str})

# 3. Überprüfe, ob die "ARS" Spalte in beiden Datenrahmen vorhanden ist
# (Falls nötig, prüfe und bereinige die Daten, falls unterschiedliche Formate verwendet werden)
print(gdf.columns)  # Gibt die Spalten der Shapefile aus
print(df.columns)   # Gibt die Spalten der CSV-Datei aus

# 3. Entferne die überflüssigen Spalten aus der CSV
df = df.drop(columns=['GF', 'AGS', 'GEN', 'BEZ'], errors='ignore')  # Fehler ignorieren, falls Spalten nicht existieren

# 4. Merge der DataFrames basierend auf der "ARS"-Spalte
merged = pd.merge(gdf, df, left_on='ARS', right_on='ARS', how='left', suffixes=('_shapefile', '_csv'))

# Überprüfen, ob die Zusammenführung erfolgreich war
print(merged.head())

# # Bereinige die Spalte 'Bevölkerung gesamt_2022', um Kommas und Punkte zu entfernen und wandle sie in float um
# merged['Bevölkerung gesamt_2022'] = merged['Bevölkerung gesamt_2022'], regex=True)
# merged['Bevölkerung gesamt_2022'] = pd.to_numeric(merged['Bevölkerung gesamt_2022'], errors='coerce')

# print(merged)


# # # 2. Definiere den Min-Max-Wertebereich für die Farbskala
# column_name = 'annual_air_temperature_max_grids_germany_annual_air_temp_max_202217_mean'  # Beispiel für Spaltenname
# vmin = merged[column_name].min()
# vmax = merged[column_name].max()

# # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
# fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
# merged.plot(column=column_name, ax=ax, legend=True,
#             legend_kwds={'orientation': "vertical"},
#             vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

# # 4. Titel und Anzeige der Karte
# plt.title(column_name, fontsize=18)
# plt.show()



import os
import matplotlib.pyplot as plt

# Pfad für das Speichern der PNG-Dateien
output_dir = "C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Niederschlag/Jaehrlich/processed_pngs"  # Passe den Pfad an

# Erstelle den Ordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Definiere die Spalten, die nicht geplottet werden sollen
exclude_columns = ['ID','AGS', 'ARS', 'GEN', 'BEZ', 'IBZ', 'GF', 'BSG', 'ADE']

# Gehe über jede numerische Spalte und erstelle ein PNG, außer die ausgeschlossenen Spalten
for column_name in merged.select_dtypes(include=['float64', 'int64']).columns:
    if column_name not in exclude_columns:
        try:
            # 2. Definiere den Min-Max-Wertebereich für die Farbskala
            vmin = merged[column_name].min()
            vmax = merged[column_name].max()

            # 3. Visualisiere die Karte mit der kontinuierlichen Farbskala
            fig, ax = plt.subplots(1, 1, figsize=(10, 10))

            # Plot mit kontinuierlichem Farbverlauf und kontrastreicherer Farbpalette
            merged.plot(column=column_name, ax=ax, legend=True,
                        legend_kwds={'orientation': "vertical"},
                        vmin=vmin, vmax=vmax, cmap='plasma')  # 'plasma' als kontrastreiche Farbpalette

            # 4. Titel und Anzeige der Karte
            plt.title(column_name, fontsize=18)

            # Speichern der Karte als PNG
            output_file = os.path.join(output_dir, f"{column_name}.png")
            plt.savefig(output_file, format='png', bbox_inches='tight')  # 'bbox_inches' stellt sicher, dass der Titel und die Legende nicht abgeschnitten werden

            # Schließe die Figur, um den Speicher zu freizugeben
            plt.close(fig)

            print(f"✓ Datei für {column_name} erfolgreich gespeichert als {output_file}")

        except Exception as e:
            print(f"✗ Fehler bei der Erstellung der Datei für {column_name} – {e}")
# Out:
# Index(['OBJID', 'BEGINN', 'ADE', 'GF', 'BSG', 'ARS', 'AGS', 'SDV_ARS', 'GEN',
#        'BEZ', 'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2',
#        'SN_G', 'FK_S3', 'NUTS', 'ARS_0', 'AGS_0', 'WSK', 'DLM_ID', 'geometry'],
#       dtype='object')
# Index(['ID', 'ARS', 'AGS', 'GEN', 'BEZ',
#        'annual_precipitation_grids_germany_annual_precipitation_202217_mean',
#        'annual_precipitation_grids_germany_annual_precipitation_202217_median'],
#       dtype='object')
#               OBJID      BEGINN  ADE  GF  BSG    ARS    AGS       SDV_ARS  \
# 0  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 1  DEBKGVG200000C75  2022-12-20    4   4    1  01001  01001  010010000000
# 2  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 3  DEBKGVG200000C76  2022-12-20    4   4    1  01002  01002  010020000000
# 4  DEBKGVG200000C77  2023-10-04    4   4    1  01003  01003  010030000000
#
#          GEN               BEZ  ...  FK_S3   NUTS         ARS_0     AGS_0  \
# 0  Flensburg  Kreisfreie Stadt  ...      R  DEF01  010010000000  01001000
# 1  Flensburg  Kreisfreie Stadt  ...      R  DEF01  010010000000  01001000
# 2       Kiel  Kreisfreie Stadt  ...      R  DEF02  010020000000  01002000
# 3       Kiel  Kreisfreie Stadt  ...      R  DEF02  010020000000  01002000
# 4     Lübeck  Kreisfreie Stadt  ...      R  DEF03  010030000000  01003000
#
#           WSK            DLM_ID  \
# 0  2008-01-01  DEBKGDL20000002R
# 1  2008-01-01  DEBKGDL20000002R
# 2  2006-01-01  DEBKGDL20000E43X
# 3  2006-01-01  DEBKGDL20000E43X
# 4  2006-02-01  DEBKGDL20000DYM9
#
#                                             geometry   ID  \
# 0  POLYGON ((3526591.850 6077123.907, 3526626.055...    1
# 1  POLYGON ((3526591.850 6077123.907, 3526626.055...  401
# 2  POLYGON ((3575940.276 6034122.503, 3575968.387...    2
# 3  POLYGON ((3575940.276 6034122.503, 3575968.387...  402
# 4  POLYGON ((3623175.007 5985702.682, 3623310.494...    3
#
#   annual_precipitation_grids_germany_annual_precipitation_202217_mean  \
# 0                                         831.229167
# 1                                                NaN
# 2                                         736.603604
# 3                                                NaN
# 4                                         590.589474
#
#   annual_precipitation_grids_germany_annual_precipitation_202217_median
# 0                                              830.5
# 1                                                NaN
# 2                                              743.0
# 3                                                NaN
# 4                                              588.0
#
# [5 rows x 29 columns]
# ✓ Datei für annual_precipitation_grids_germany_annual_precipitation_202217_mean erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Niederschlag/Jaehrlich/processed_pngs\annual_precipitation_grids_germany_annual_precipitation_202217_mean.png
# ✓ Datei für annual_precipitation_grids_germany_annual_precipitation_202217_median erfolgreich gespeichert als C:/Users/agnes/Documents/EAGLE/Innovation_Lab/Daten/DWDdaten/Kreisebene/Niederschlag/Jaehrlich/processed_pngs\annual_precipitation_grids_germany_annual_precipitation_202217_median.png
